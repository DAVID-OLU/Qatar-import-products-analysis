# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.graph_objs as go
from plotly.offline import iplot
sns.set()
pd.options.display.max_columns = 999

# %%
data = pd.read_excel('data/qatar-imports-2019-2024.xlsx')

# %%
data.head()
# Out:
#    Year Quarter  Month      HS8  \
# 0  2024      Q1      2  3071100
# 1  2024      Q1      2  3074200
# 2  2024      Q1      2  4012030
# 3  2024      Q1      2  4015030
# 4  2024      Q1      2  4022190
#
#                                             التفاصيل  \
# 0                         المحار، حي أو طازج أو مبرد
# 1                   حبار وسبيدج ، حي أو طازج أو مبرد
# 2  ألبان وقشدة، غير مركزة ولا محتوية على سكر مضاف...
# 3  لبن (حليب) طويل الأجل بعبوات تزيد سعتها عن لتر...
# 4                            غيرها من الحليب المسحوق
#
#                                              Details دولة المنشأ  \
# 0                      Oysters,Live Fresh Or Chilled  سلطنة عمان
# 1    Live, fresh or chilled of Cuttle fish and squid  سلطنة عمان
# 2          Long Life Milk , In Packing Exceeding 1 L     المانيا
# 3  Long Life Milk, In Containers Exceeding 1 Litr...       فرنسا
# 4                                Milk & Cream, Other  سلطنة عمان
#
# ...

# %%
print(data.shape)
# Out:
# (830353, 11)

# %%
data['HS8'].nunique()
# Out:
# 7140

# %%
print(data.isnull().sum())
# Out:
# Year                  0
# Quarter               0
# Month                 0
# HS8                   0
# التفاصيل              0
# Details               0
# دولة المنشأ          72
# Country of Origin    72
# Quantity              0
# Weight (KG)           0
# Value (QR)            0
# dtype: int64

# %%
data[data['Country of Origin'].isna()].head()
# Out:
#        Year Quarter  Month  HS8  \
# 39194  2024      Q1      3    0
# 51385  2024      Q3      9    0
# 56728  2022      Q3      8    0
# 69742  2023      Q3      9    0
# 75477  2023      Q3      8    0
#
#                                                 التفاصيل  \
# 39194                 أخرى القيم أقل من 20 ألف ريال قطري
# 51385                 أخرى القيم أقل من 20 ألف ريال قطري
# 56728  أخرى تشمل السلع التي قيمتها أقل من 50 ألف ريال...
# 69742  أخرى تشمل السلع التي قيمتها أقل من 50 ألف ريال...
# 75477  أخرى تشمل السلع التي قيمتها أقل من 50 ألف ريال...
#
#                                                  Details دولة المنشأ  \
# 39194               Other Value Less Than 20 Thousand QR         NaN
# 51385               Other Value Less Than 20 Thousand QR         NaN
# 56728  Other Include Items Which Value Less Than 50 T...         NaN
# 69742  Other Include Items Which Value Less Than 50 T...         NaN
# 75477  Other Include Items Which Value Less Than 50 T...         NaN
#
# ...

# %%
print(data.dtypes)
# Out:
# Year                   int64
# Quarter               object
# Month                  int64
# HS8                    int64
# التفاصيل              object
# Details               object
# دولة المنشأ           object
# Country of Origin     object
# Quantity               int64
# Weight (KG)          float64
# Value (QR)           float64
# dtype: object

# %%
print(data.loc[data['HS8'] == '0', 'Country of Origin'].unique())
# Out:
# []

# %%
data = data.dropna(subset=['Country of Origin'])

# %%
print(data.isna().sum())
# Out:
# Year                 0
# Quarter              0
# Month                0
# HS8                  0
# التفاصيل             0
# Details              0
# دولة المنشأ          0
# Country of Origin    0
# Quantity             0
# Weight (KG)          0
# Value (QR)           0
# dtype: int64

# %%
data.drop(columns=['التفاصيل', 'دولة المنشأ'], inplace=True)
# Out:
# /var/folders/5s/mv4171b97vd_bhbvhbg7yx6h0000gn/T/ipykernel_87360/1409997919.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data.columns
# Out:
# Index(['Year', 'Quarter', 'Month', 'HS8', 'Details', 'Country of Origin',
#        'Quantity', 'Weight (KG)', 'Value (QR)'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Year                   int64
# Quarter               object
# Month                  int64
# HS8                    int64
# Details               object
# Country of Origin     object
# Quantity               int64
# Weight (KG)          float64
# Value (QR)           float64
# dtype: object

# %%
data['Date'] = pd.to_datetime(data['Year'].astype(str) + '-' + data['Month'].astype(str) + '-01')
# Out:
# /var/folders/5s/mv4171b97vd_bhbvhbg7yx6h0000gn/T/ipykernel_87360/3636204238.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data.dtypes
# Out:
# Year                          int64
# Quarter                      object
# Month                         int64
# HS8                           int64
# Details                      object
# Country of Origin            object
# Quantity                      int64
# Weight (KG)                 float64
# Value (QR)                  float64
# Date                 datetime64[ns]
# dtype: object

# %%
print(data.isna().sum())
# Out:
# Year                 0
# Quarter              0
# Month                0
# HS8                  0
# Details              0
# Country of Origin    0
# Quantity             0
# Weight (KG)          0
# Value (QR)           0
# Date                 0
# dtype: int64

# %%
data["PricePerUnit"] = data["Value (QR)"] / data["Quantity"]
data["PricePerKG"] = data["Value (QR)"] / data["Weight (KG)"]

# %%
data.columns
# Out:
# Index(['Year', 'Quarter', 'Month', 'HS8', 'Details', 'Country of Origin',
#        'Quantity', 'Weight (KG)', 'Value (QR)', 'Date', 'PricePerUnit',
#        'PricePerKG'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Year                          int64
# Quarter                      object
# Month                         int64
# HS8                           int64
# Details                      object
# Country of Origin            object
# Quantity                      int64
# Weight (KG)                 float64
# Value (QR)                  float64
# Date                 datetime64[ns]
# PricePerUnit                float64
# PricePerKG                  float64
# dtype: object

# %%
data.to_excel("new_data.xlsx", index=False)
